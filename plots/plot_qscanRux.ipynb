# %%
import numpy as np
import scipy.signal as sig
import matplotlib.pyplot as plt
import pandas as pd

from pycbc.types import TimeSeries
from pycbc.filter.qtransform import qseries

# %%
import jax
import jax.numpy as jnp

# %%
from functools import partial

import antiglitch
from antiglitch import rfft, irfft
from antiglitch import center
from antiglitch import downsample_invasd
import matplotlib.pylab as pylab
params = {'legend.fontsize': 18,
#        'figure.figsize': (16, 16),
         'axes.labelsize': 18,
         'axes.titlesize':18,
         'xtick.labelsize':18,
         'ytick.labelsize':18}
pylab.rcParams.update(params)

# %%
ml_key = {'tomte': 'Tomte', 'blip' : 'Blip', 'koi' : 'Koi_Fish', 'lowblip': 'Blip_Low_Frequency'}

# %%
def upsample_invasd(invasd, tlen):
    """Reduce frequency resolution of the inverse ASD to a given number of time samples"""
    workspace = np.zeros(tlen, dtype=invasd.dtype)
    td = irfft(invasd)
    workspace[:len(td)] = sig.hann(len(td))*np.roll(td, len(td)//2)
    tmp = np.abs(rfft(workspace))
    tmp[0] = 0.
    return tmp

# %%
freqs = jnp.linspace(0, 4096, 513)
freqs2 = jnp.linspace(0, 4096, 1+4*4096)

@jax.jit
def fsignal(freqs, f0, gbw):
    return jnp.exp(-0.5*gbw*(jnp.log(freqs) - jnp.log(f0))**2)

def fglitch_normed(freqs, invasd, amp_r, amp_i, f0, gbw, time, **kwargs):
    raw = invasd*fsignal(freqs, f0, gbw)
    norm = 1./jnp.sqrt(jnp.sum(jnp.real(raw*raw.conjugate())))
    ftmp = norm*(amp_r+1.j*amp_i)*raw*jnp.exp(-2.j*jnp.pi*(time*freqs))
    return ftmp

# %%
datadir = '/Users/ruxandra/src/antiglitch/notebooks/data/'
antiglitch.utils.datadir = datadir

# %%
df = pd.read_json('../data/all_PE_mle.json')

# %%
key = ('V1', 'koi')
ifo, kind = key
df.query(f"ifo == '{ifo}' and ml_label == '{ml_key[kind]}' and snr > 100")
# Out:
#            amp_i       amp_r         f0       gbw          time         amp  \
# 3630 -252.784180   -5.125977  11.295851  1.938418 -3.511285e-03  252.836147
# 3633 -108.207031  188.484375  11.591648  1.190371  1.757531e-03  217.336424
# 3637 -126.395508 -280.604492  15.491475  2.379886 -2.630013e-03  307.757543
# 3639 -206.610352   93.967773  19.493036  4.409707 -4.679328e-04  226.975285
# 3641   58.583984  -41.770508  11.124094  0.568822  1.338618e-03   71.950389
# 3647 -108.906250   -7.516602  14.084297  0.611868  4.547276e-04  109.165336
# 3654  -97.541992    1.295898  18.206362  0.402192  6.406750e-05   97.550600
# 3656  -16.639648  101.565430  11.543350  0.844133  1.179197e-03  102.919456
# 3658   17.125977   71.605469  10.904919  0.419534  1.498899e-03   73.625011
# 3659  -48.176758   72.361328  19.453644  4.595993 -1.303867e-03   86.931938
# 3663  143.272461    3.278320  10.669178  1.144157 -1.418556e-03  143.309963
# 3675  -61.239258   64.760742  11.280947  1.240224 -1.622752e-03   89.130244
# 3677 -108.625000  129.816406  11.284261  1.184669 -4.656492e-04  169.268101
#
#       ml_label  num  frequency
# 3630  Koi_Fish    3  11.295851
# 3633  Koi_Fish    6  11.591648
# 3637  Koi_Fish   10  15.491475
# 3639  Koi_Fish   12  19.493036
# 3641  Koi_Fish   14  11.124094
# 3647  Koi_Fish   20  14.084297
# 3654  Koi_Fish   27  18.206362
# 3656  Koi_Fish   29  11.543350
# 3658  Koi_Fish   31  10.904919
# 3659  Koi_Fish   32  19.453644
# 3663  Koi_Fish   36  10.669178
# 3675  Koi_Fish   48  11.280947
# 3677  Koi_Fish   50  11.284261
# 3678  Koi_Fish   51  10.846481
# 3687  Koi_Fish   60  26.477612
# 3689  Koi_Fish   62  11.937114
# 3690  Koi_Fish   63  14.459909
# 3695  Koi_Fish   68  14.196764
# 3699  Koi_Fish   72  10.288731
# 3704  Koi_Fish   77  49.225826
# 3705  Koi_Fish   78  11.461794
# 3716  Koi_Fish   89  10.972902
# 3723  Koi_Fish   96  14.159614
# 3731  Koi_Fish  104  11.140753
# 3732  Koi_Fish  105  11.395907
# 3734  Koi_Fish  107  15.375369
# 3739  Koi_Fish  112  11.293160
# 3741  Koi_Fish  114  11.283828
# 3742  Koi_Fish  115  11.478238
# 3744  Koi_Fish  117  10.557846
# 3748  Koi_Fish  121  12.389687
# 3753  Koi_Fish  126  17.083599
# 3757  Koi_Fish  130  13.311546
# 3760  Koi_Fish  133  12.446755
# 3761  Koi_Fish  134  11.289072
# 3766  Koi_Fish  139  11.472011
# 3772  Koi_Fish  145  16.228649
# 3775  Koi_Fish  148  11.419049
# 3783  Koi_Fish  156  11.014173
# 3786  Koi_Fish  159  11.146507
# 3788  Koi_Fish  161  51.196629
# 3793  Koi_Fish  166  13.331675
# 3794  Koi_Fish  167  10.668153
# 3797  Koi_Fish  170  20.595078
# 3809  Koi_Fish  182  11.503983
# 3810  Koi_Fish  183  11.154047
# 3817  Koi_Fish  190  11.658462
# 3820  Koi_Fish  193  13.049374

# %%
def plot_qscan(ifo, kind, num):
    npz = np.load(f"{datadir}/{ifo}-{kind}-{num:04d}.npz")
    invasd = ((4096.*npz['psd'])**-0.5)[:4097]
    invasd[:10] = 0.

    invasd2 = upsample_invasd(invasd, 4*8192)
    
    snip = antiglitch.SnippetNormed(ifo, kind, num)
    inf = df.query(f"ifo == '{ifo}' and ml_label == '{ml_key[kind]}' and num == {num}").iloc[0]
    snip.set_infer(inf)
    
    fglitch2 = fglitch_normed(freqs2, invasd2, **inf)
    
    ts1 = TimeSeries(snip.whts_long[8192:-8192], delta_t = 1/8192)
    ts2 = TimeSeries((snip.whts_long - center(irfft(fglitch2)))[8192:-8192], delta_t = 1/8192)
    ts3 = TimeSeries((center(irfft(fglitch2)))[8192:-8192], delta_t = 1/8192)

    q = 6.
    qtt1 = np.vstack([qseries(ts1.to_frequencyseries(), q, ff)[::32] for ff in np.arange(10,2048,1)])
    qtt2 = np.vstack([qseries(ts2.to_frequencyseries(), q, ff)[::32] for ff in np.arange(10,2048,1)])

    fig, ax = plt.subplots(2,2, figsize=(12,8))
    ax[0,0].set_yscale('log')
    ax[0,0].set_xlim(-500,500)
    ax[1,0].set_yscale('log')
    ax[1,0].set_xlim(-500,500)
    ax[0,0].pcolormesh(np.linspace(-1000,1000,512), np.arange(10,2048,1), qtt1, vmin=0, vmax=25.5)
    ax[0,0].set_xlabel('Time [ms]',fontsize=20)
    ax[0,0].set_ylabel('Frequency [Hz]',fontsize=20)
    
    ax[1,0].pcolormesh(np.linspace(-1000,1000,512), np.arange(10,2048,1), qtt2, vmin=0, vmax=25.5)
    ax[1,0].set_xlabel('Time [ms]',fontsize=20)
    ax[1,0].set_ylabel('Frequency [Hz]',fontsize=20)

    ax[0,1].loglog(freqs, np.abs(rfft(snip.whts)), c='k', lw=2, label='Original')
    ax[0,1].loglog(freqs, np.abs(rfft(snip.whts - snip.glitch)), c='g', lw=1, ls=':', label='Residual')
    ax[0,1].loglog(freqs, np.abs(rfft(snip.glitch)), c='r', lw=1, label='Model')
    ax[0,1].set_xlabel('Frequency [Hz]', fontsize=20)
    ax[0,1].set_ylabel('Whitened amplitude',fontsize=20)
#    ax[0,1].legend(fontsize=18, loc='upper right')

    ax[0,1].set_ylim(1e-2,1.0e2)
    ax[1,1].plot(np.linspace(-62.5, 62.5, 1024), snip.whts, c='k', lw=2,label='Original')
    ax[1,1].plot(np.linspace(-62.5, 62.5, 1024), snip.whts - snip.glitch, c='g', lw=1, ls=':', label='Residual')
    ax[1,1].plot(np.linspace(-62.5, 62.5, 1024), snip.glitch, c='r', lw=1,label='Model')
    ax[1,1].legend(fontsize=20, loc='lower right')
#    ax[1,1].legend(fontsize=19, loc='lower right')
    ax[1,1].set_xlabel('Time [ms]',fontsize=20)
    ax[1,1].set_ylabel('Whitened amplitude',fontsize=20)
    fig.tight_layout()
#    fig.tight_layout(pad=2.0)
    fig.savefig(f"{ifo}-{kind}-{num}-qscan.png")

# %%
plot_qscan('H1', 'blip', 498)
# Out:
# /var/folders/9r/2rjfr67j39153lp1r6y1_jym0000gr/T/ipykernel_39540/4060261727.py:3: RuntimeWarning: divide by zero encountered in power
#   invasd = ((4096.*npz['psd'])**-0.5)[:4097]

# %%
plot_qscan('V1', 'koi', 20)
# Out:
# /var/folders/9r/2rjfr67j39153lp1r6y1_jym0000gr/T/ipykernel_39540/271705541.py:3: RuntimeWarning: divide by zero encountered in power
#   invasd = ((4096.*npz['psd'])**-0.5)[:4097]

# %%
plot_qscan('L1', 'tomte', 0)
# Out:
# /var/folders/9r/2rjfr67j39153lp1r6y1_jym0000gr/T/ipykernel_39540/2770072697.py:3: RuntimeWarning: divide by zero encountered in power
#   invasd = ((4096.*npz['psd'])**-0.5)[:4097]

# %%
plot_qscan('L1', 'lowblip', 4)
# Out:
# /var/folders/9r/2rjfr67j39153lp1r6y1_jym0000gr/T/ipykernel_39540/500973932.py:3: RuntimeWarning: divide by zero encountered in power
#   invasd = ((4096.*npz['psd'])**-0.5)[:4097]
